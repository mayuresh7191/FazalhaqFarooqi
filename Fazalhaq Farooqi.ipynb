# %%
import pandas as pd
import numpy as np

# Load the dataset
file_path = r"C:\Users\mayur\Downloads\T20wc2024.xlsx"
wc_data = pd.read_excel(file_path)

# %%
def categorize_overs(overs):
    if overs < 6.0:
        return 'Power play'
    elif overs < 15.0:
        return 'Middle overs'
    else:
        return 'Death'

# %%
wc_data.columns
# Out:
# Index(['match_id', 'custom_match_id', 'season', 'type_clean',
#        'competition_code', 'competition', 'gender', 'venue', 'date',
#        'timestamp', 'inning_number', 'id', 'overs_unique', 'overs_actual',
#        'over_number', 'ball_number', 'balls_remaining', 'total_inning_runs',
#        'run_rate', 'target', 'total_inning_wickets', 'bowl_team',
#        'bowl_team_id', 'bowl_team_abbr', 'bowler_cricinfo_id',
#        'bowler_player_id', 'bowler', 'bowling_hand', 'bowling_pacespin',
#        'bowling_style_long', 'bowler_wickets_cumulative', 'title', 'bat_team',
#        'bat_team_id', 'bat_team_abbr', 'batter_cricinfo_id',
#        'batter_player_id', 'batter', 'batting_style', 'batter_runs_cumulative',
#        'total_runs', 'runs_off_bat', 'byes', 'legbyes', 'wides', 'noballs',
#        'penalties', 'extras', 'out_player_cricinfo_id', 'out_player_id',
#        'out_player', 'dismissal_type', 'dismissal_text_shot',
# ...

# %%
farooqi_data = wc_data[wc_data['bowler']=='Fazalhaq Farooqi']

# %%
farooqi_data
# Out:
#       match_id             custom_match_id  season type_clean  \
# 1067   1415705  ICCMTWC_AFG_UGA_2024-06-03    2024        T20
# 1068   1415705  ICCMTWC_AFG_UGA_2024-06-03    2024        T20
# 1069   1415705  ICCMTWC_AFG_UGA_2024-06-03    2024        T20
# 1070   1415705  ICCMTWC_AFG_UGA_2024-06-03    2024        T20
# 1071   1415705  ICCMTWC_AFG_UGA_2024-06-03    2024        T20
# ...        ...                         ...     ...        ...
# 9885   1415748  ICCMTWC_AFG_AUS_2024-06-22    2024        T20
# 9886   1415748  ICCMTWC_AFG_AUS_2024-06-22    2024        T20
# 9887   1415748  ICCMTWC_AFG_AUS_2024-06-22    2024        T20
# 9888   1415748  ICCMTWC_AFG_AUS_2024-06-22    2024        T20
# 9889   1415748  ICCMTWC_AFG_AUS_2024-06-22    2024        T20
#
#      competition_code              competition gender  \
# 1067          ICCMTWC  ICC Men's T20 World Cup   male
# 1068          ICCMTWC  ICC Men's T20 World Cup   male
# 1069          ICCMTWC  ICC Men's T20 World Cup   male
# ...

# %%
farooqi_data.drop(columns=['custom_match_id', 'season', 'date','inning_number', 'id','target'],inplace=True)
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_27948\639145530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farooqi_data.drop(columns=['custom_match_id', 'season', 'date','inning_number', 'id','target'],inplace=True)

# %%
farooqi_data
# Out:
#       match_id type_clean competition_code              competition gender  \
# 1067   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1068   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1069   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1070   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1071   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ...        ...        ...              ...                      ...    ...
# 9885   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9886   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9887   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9888   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9889   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
# ...

# %%
farooqi_data.drop(columns=['balls_remaining', 'dismissal_text_long','dismissal_text_commentary','out_player_cricinfo_id', 'out_player_id'],inplace=True)
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_27948\2171433851.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farooqi_data.drop(columns=['balls_remaining', 'dismissal_text_long','dismissal_text_commentary','out_player_cricinfo_id', 'out_player_id'],inplace=True)

# %%
farooqi_data.columns
# Out:
# Index(['match_id', 'type_clean', 'competition_code', 'competition', 'gender',
#        'venue', 'timestamp', 'overs_unique', 'overs_actual', 'over_number',
#        'ball_number', 'total_inning_runs', 'run_rate', 'total_inning_wickets',
#        'bowl_team', 'bowl_team_id', 'bowl_team_abbr', 'bowler_cricinfo_id',
#        'bowler_player_id', 'bowler', 'bowling_hand', 'bowling_pacespin',
#        'bowling_style_long', 'bowler_wickets_cumulative', 'title', 'bat_team',
#        'bat_team_id', 'bat_team_abbr', 'batter_cricinfo_id',
#        'batter_player_id', 'batter', 'batting_style', 'batter_runs_cumulative',
#        'total_runs', 'runs_off_bat', 'byes', 'legbyes', 'wides', 'noballs',
#        'penalties', 'extras', 'out_player', 'dismissal_type',
#        'dismissal_text_shot'],
#       dtype='object')

# %%
farooqi_data.drop(columns=['bowl_team_id', 'bowl_team_abbr', 'bowler_cricinfo_id','bowling_hand', 'bowling_pacespin','bowling_style_long','bat_team_id', 'bat_team_abbr', 'batter_cricinfo_id','batter_player_id'],inplace=True)
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_27948\2732075994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farooqi_data.drop(columns=['bowl_team_id', 'bowl_team_abbr', 'bowler_cricinfo_id','bowling_hand', 'bowling_pacespin','bowling_style_long','bat_team_id', 'bat_team_abbr', 'batter_cricinfo_id','batter_player_id'],inplace=True)

# %%
farooqi_data.columns
# Out:
# Index(['match_id', 'type_clean', 'competition_code', 'competition', 'gender',
#        'venue', 'timestamp', 'overs_unique', 'overs_actual', 'over_number',
#        'ball_number', 'total_inning_runs', 'run_rate', 'total_inning_wickets',
#        'bowl_team', 'bowler_player_id', 'bowler', 'bowler_wickets_cumulative',
#        'title', 'bat_team', 'batter', 'batting_style',
#        'batter_runs_cumulative', 'total_runs', 'runs_off_bat', 'byes',
#        'legbyes', 'wides', 'noballs', 'penalties', 'extras', 'out_player',
#        'dismissal_type', 'dismissal_text_shot'],
#       dtype='object')

# %%
farooqi_data
# Out:
#       match_id type_clean competition_code              competition gender  \
# 1067   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1068   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1069   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1070   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1071   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ...        ...        ...              ...                      ...    ...
# 9885   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9886   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9887   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9888   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9889   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
# ...

# %%
farooqi_data.drop(columns=['bowl_team','bowler_player_id','title'],inplace=True)
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_27948\4193923942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farooqi_data.drop(columns=['bowl_team','bowler_player_id','title'],inplace=True)

# %%
farooqi_data.columns
# Out:
# Index(['match_id', 'type_clean', 'competition_code', 'competition', 'gender',
#        'venue', 'timestamp', 'overs_unique', 'overs_actual', 'over_number',
#        'ball_number', 'total_inning_runs', 'run_rate', 'total_inning_wickets',
#        'bowler', 'bowler_wickets_cumulative', 'bat_team', 'batter',
#        'batting_style', 'batter_runs_cumulative', 'total_runs', 'runs_off_bat',
#        'byes', 'legbyes', 'wides', 'noballs', 'penalties', 'extras',
#        'out_player', 'dismissal_type', 'dismissal_text_shot'],
#       dtype='object')

# %%
farooqi_data.drop(columns=['total_inning_runs', 'run_rate', 'total_inning_wickets','batter_runs_cumulative'],inplace=True)
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_27948\3791462166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farooqi_data.drop(columns=['total_inning_runs', 'run_rate', 'total_inning_wickets','batter_runs_cumulative'],inplace=True)

# %%
farooqi_data.columns
# Out:
# Index(['match_id', 'type_clean', 'competition_code', 'competition', 'gender',
#        'venue', 'timestamp', 'overs_unique', 'overs_actual', 'over_number',
#        'ball_number', 'bowler', 'bowler_wickets_cumulative', 'bat_team',
#        'batter', 'batting_style', 'total_runs', 'runs_off_bat', 'byes',
#        'legbyes', 'wides', 'noballs', 'penalties', 'extras', 'out_player',
#        'dismissal_type', 'dismissal_text_shot'],
#       dtype='object')

# %%
farooqi_data
# Out:
#       match_id type_clean competition_code              competition gender  \
# 1067   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1068   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1069   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1070   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1071   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ...        ...        ...              ...                      ...    ...
# 9885   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9886   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9887   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9888   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9889   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
# ...

# %%
farooqi_data['extras'].value_counts()
# Out:
# extras
# 0    122
# 1     10
# 2      2
# 4      2
# 5      1
# Name: count, dtype: int64

# %%
farooqi_data['out_player'].value_counts()
# Out:
# out_player
# Ronak Patel         1
# Roger Mukasa        1
# Riazat Ali Shah     1
# Brian Masaba        1
# Robinson Obuya      1
# Finn Allen          1
# Devon Conway        1
# Daryl Mitchell      1
# Matt Henry          1
# Lega Siaka          1
# Sese Bau            1
# Alei Nao            1
# Rohit Sharma        1
# Suryakumar Yadav    1
# Ravindra Jadeja     1
# Name: count, dtype: int64

# %%
farooqi_data['Phase'] = farooqi_data["overs_actual"].apply(categorize_overs)
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_27948\2220611033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farooqi_data['Phase'] = farooqi_data["overs_actual"].apply(categorize_overs)

# %%
farooqi_data
# Out:
#       match_id type_clean competition_code              competition gender  \
# 1067   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1068   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1069   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1070   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1071   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ...        ...        ...              ...                      ...    ...
# 9885   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9886   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9887   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9888   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9889   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
# ...

# %%
farooqi_data['noballs'].value_counts()
# Out:
# noballs
# 0    128
# Name: count, dtype: int64

# %%
farooqi_data=farooqi_data[farooqi_data['wides']==0]

# %%
farooqi_data=farooqi_data[farooqi_data['noballs']==0]

# %%
farooqi_data
# Out:
#       match_id type_clean competition_code              competition gender  \
# 1067   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1068   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1069   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1070   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1071   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ...        ...        ...              ...                      ...    ...
# 9884   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9885   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9886   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9887   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9889   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
# ...

# %%
farooqi_data['ball_number'].value_counts()
# Out:
# ball_number
# 2    21
# 1    20
# 3    20
# 4    20
# 6    20
# 5    19
# 7     6
# 8     2
# Name: count, dtype: int64

# %%
farooqi_data.columns
# Out:
# Index(['match_id', 'type_clean', 'competition_code', 'competition', 'gender',
#        'venue', 'timestamp', 'overs_unique', 'overs_actual', 'over_number',
#        'ball_number', 'bowler', 'bowler_wickets_cumulative', 'bat_team',
#        'batter', 'batting_style', 'total_runs', 'runs_off_bat', 'byes',
#        'legbyes', 'wides', 'noballs', 'penalties', 'extras', 'out_player',
#        'dismissal_type', 'dismissal_text_shot', 'Phase'],
#       dtype='object')

# %%
farooqi_data.drop(columns=['bowler','bowler_wickets_cumulative', 'byes', 'legbyes', 'wides', 'noballs','penalties', 'extras'],inplace=True)

# %%
farooqi_data
# Out:
#       match_id type_clean competition_code              competition gender  \
# 1067   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1068   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1069   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1070   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1071   1415705        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ...        ...        ...              ...                      ...    ...
# 9884   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9885   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9886   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9887   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9889   1415748        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
# ...

# %%
farooqi_data.drop(columns=['match_id','runs_off_bat','out_player'],inplace=True)

# %%
farooqi_data
# Out:
#      type_clean competition_code              competition gender  \
# 1067        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1068        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1069        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1070        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1071        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ...         ...              ...                      ...    ...
# 9884        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9885        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9886        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9887        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 9889        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
#                                          venue                 timestamp  \
# 1067                Providence Stadium, Guyana  2024-06-04T02:23:28.000Z
# ...

# %%
farooqi_data.reset_index(inplace=True)

# %%
farooqi_data
# Out:
#      index type_clean competition_code              competition gender  \
# 0     1067        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1     1068        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 2     1069        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 3     1070        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 4     1071        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ..     ...        ...              ...                      ...    ...
# 123   9884        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 124   9885        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 125   9886        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 126   9887        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 127   9889        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
#                                         venue                 timestamp  \
# ...

# %%
farooqi_data.rename(columns = {'total_runs':'Outcome'}, inplace = True)

# %%
farooqi_data
# Out:
#      index type_clean competition_code              competition gender  \
# 0     1067        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1     1068        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 2     1069        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 3     1070        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 4     1071        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ..     ...        ...              ...                      ...    ...
# 123   9884        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 124   9885        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 125   9886        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 126   9887        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 127   9889        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
#                                         venue                 timestamp  \
# ...

# %%
farooqi_data['Wicket'] = farooqi_data['dismissal_type'].apply(lambda x: 0 if pd.isna(x) else 1)

# %%
farooqi_data
# Out:
#      index type_clean competition_code              competition gender  \
# 0     1067        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1     1068        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 2     1069        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 3     1070        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 4     1071        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ..     ...        ...              ...                      ...    ...
# 123   9884        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 124   9885        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 125   9886        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 126   9887        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 127   9889        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
#                                         venue                 timestamp  \
# ...

# %%
farooqi_data.drop(columns=['dismissal_type'],inplace=True)

# %%
farooqi_data
# Out:
#      index type_clean competition_code              competition gender  \
# 0     1067        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1     1068        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 2     1069        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 3     1070        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 4     1071        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ..     ...        ...              ...                      ...    ...
# 123   9884        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 124   9885        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 125   9886        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 126   9887        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 127   9889        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
#                                         venue                 timestamp  \
# ...

# %%
farooqi_data.reset_index(drop=True, inplace=True)

# %%
farooqi_data
# Out:
#      index type_clean competition_code              competition gender  \
# 0     1067        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1     1068        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 2     1069        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 3     1070        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 4     1071        T20          ICCMTWC  ICC Men's T20 World Cup   male
# ..     ...        ...              ...                      ...    ...
# 123   9884        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 124   9885        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 125   9886        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 126   9887        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 127   9889        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
#                                         venue                 timestamp  \
# ...

# %%
farooqi_data.drop(columns=['index'],inplace=True)

# %%
farooqi_data
# Out:
#     type_clean competition_code              competition gender  \
# 0          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 2          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 3          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 4          T20          ICCMTWC  ICC Men's T20 World Cup   male
# ..         ...              ...                      ...    ...
# 123        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 124        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 125        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 126        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 127        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
#                                         venue                 timestamp  \
# 0                  Providence Stadium, Guyana  2024-06-04T02:23:28.000Z
# ...

# %%
farooqi_data.rename(columns = {'bat_team':'Opponent Team'}, inplace = True)

# %%
farooqi_data.rename(columns = {'batter':'Batter'}, inplace = True)

# %%
farooqi_data
# Out:
#     type_clean competition_code              competition gender  \
# 0          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 2          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 3          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 4          T20          ICCMTWC  ICC Men's T20 World Cup   male
# ..         ...              ...                      ...    ...
# 123        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 124        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 125        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 126        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 127        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
#                                         venue                 timestamp  \
# 0                  Providence Stadium, Guyana  2024-06-04T02:23:28.000Z
# ...

# %%
farooqi_data.loc[:,['overs_actual','over_number','ball_number','Opponent Team','Batter','Outcome','Wicket','Phase','dismissal_text_shot','batting_style','venue']]
# Out:
#      overs_actual  over_number  ball_number Opponent Team           Batter  \
# 0             0.1            1            1        Uganda      Ronak Patel
# 1             0.2            1            2        Uganda      Ronak Patel
# 2             0.3            1            3        Uganda     Roger Mukasa
# 3             0.4            1            4        Uganda  Riazat Ali Shah
# 4             0.5            1            5        Uganda  Riazat Ali Shah
# ..            ...          ...          ...           ...              ...
# 123          18.2           19            2     Australia   Josh Hazlewood
# 124          18.3           19            3     Australia       Adam Zampa
# 125          18.4           19            4     Australia       Adam Zampa
# 126          18.5           19            5     Australia       Adam Zampa
# 127          18.6           19            7     Australia   Josh Hazlewood
#
# ...

# %%
farooqi_data.rename(columns = {'dismissal_text_shot':'Wicket Type'}, inplace = True)

# %%
farooqi_data
# Out:
#     type_clean competition_code              competition gender  \
# 0          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 1          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 2          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 3          T20          ICCMTWC  ICC Men's T20 World Cup   male
# 4          T20          ICCMTWC  ICC Men's T20 World Cup   male
# ..         ...              ...                      ...    ...
# 123        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 124        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 125        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 126        T20          ICCMTWC  ICC Men's T20 World Cup   male
# 127        T20          ICCMTWC  ICC Men's T20 World Cup   male
#
#                                         venue                 timestamp  \
# 0                  Providence Stadium, Guyana  2024-06-04T02:23:28.000Z
# ...

# %%
farooqi_data.loc[:,['overs_actual','over_number','ball_number','Opponent Team','Batter','Outcome','Wicket','Phase','Wicket Type','batting_style','venue']]
# Out:
#      overs_actual  over_number  ball_number Opponent Team           Batter  \
# 0             0.1            1            1        Uganda      Ronak Patel
# 1             0.2            1            2        Uganda      Ronak Patel
# 2             0.3            1            3        Uganda     Roger Mukasa
# 3             0.4            1            4        Uganda  Riazat Ali Shah
# 4             0.5            1            5        Uganda  Riazat Ali Shah
# ..            ...          ...          ...           ...              ...
# 123          18.2           19            2     Australia   Josh Hazlewood
# 124          18.3           19            3     Australia       Adam Zampa
# 125          18.4           19            4     Australia       Adam Zampa
# 126          18.5           19            5     Australia       Adam Zampa
# 127          18.6           19            7     Australia   Josh Hazlewood
#
#      Outcome  Wicket       Phase Wicket Type batting_style  \
# ...

# %%
farooqi_data.columns
# Out:
# Index(['type_clean', 'competition_code', 'competition', 'gender', 'venue',
#        'timestamp', 'overs_unique', 'overs_actual', 'over_number',
#        'ball_number', 'Opponent Team', 'Batter', 'batting_style', 'Outcome',
#        'Wicket Type', 'Phase', 'Wicket'],
#       dtype='object')

# %%
farooqi_data.drop(columns=['type_clean', 'competition_code', 'competition', 'gender','timestamp'],inplace=True)

# %%
farooqi_data
# Out:
#                                         venue  overs_unique  overs_actual  \
# 0                  Providence Stadium, Guyana          0.01           0.1
# 1                  Providence Stadium, Guyana          0.02           0.2
# 2                  Providence Stadium, Guyana          0.03           0.3
# 3                  Providence Stadium, Guyana          0.04           0.4
# 4                  Providence Stadium, Guyana          0.05           0.5
# ..                                        ...           ...           ...
# 123  Arnos Vale Ground, Kingstown, St Vincent         18.02          18.2
# 124  Arnos Vale Ground, Kingstown, St Vincent         18.03          18.3
# 125  Arnos Vale Ground, Kingstown, St Vincent         18.04          18.4
# 126  Arnos Vale Ground, Kingstown, St Vincent         18.05          18.5
# 127  Arnos Vale Ground, Kingstown, St Vincent         18.07          18.6
#
#      over_number  ball_number Opponent Team           Batter batting_style  \
# ...

# %%
farooqi_data.to_excel("farooqi.xlsx")
